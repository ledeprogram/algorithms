# %%
def sort(list):
    times = len(list) - 1
    # create a new empty list to add sorted values 
    sorted = []


    while times + 1> 0:
        min = list[0]
        for item in list:
             if item < min:
                    min = item
        # after finding the smallest element, append it to the new sorted list
        sorted.append(min)
        
        #remove the smallest element from the original list 
        list.remove(min)
        
        #incremenet the number of times, in order to get closer to the condition
        # that will halt this while loops 
        times = times - 1
    
    return sorted

# %%
sort([3,56,12,4,56,81,2])
# Out:
# [2, 3, 4, 12, 56, 56, 81]

# %%
sort([5,6,2,100,4,6,20000])
# Out:
# [2, 4, 5, 6, 6, 100, 20000]

# %%
from random import randint

def random_num_gen(x):
    random_list = [] 
    count = 0 
    while count < x:
        random_list.append(randint(0,1000))
        count = count + 1
    return random_list

# %%
ten_sample = random_num_gen(10)

# %%
hundred_sample = random_num_gen(100)

# %%
thousand_sample = random_num_gen(1000)

# %%
# %time sort(ten_sample)
# Out:
# CPU times: user 28 µs, sys: 1e+03 ns, total: 29 µs
# Wall time: 35 µs
# [11, 114, 253, 340, 351, 409, 531, 585, 721, 771]

# %%
# %time sort(hundred_sample)
# Out:
# CPU times: user 346 µs, sys: 1e+03 ns, total: 347 µs
# Wall time: 349 µs
# [22,
#  24,
#  73,
#  91,
#  101,
#  103,
#  103,
#  105,
#  111,
#  127,
#  134,
#  140,
#  150,
#  151,
#  157,
#  165,
#  167,
#  173,
#  184,
#  194,
#  196,
#  254,
#  255,
#  263,
#  290,
#  300,
#  322,
#  322,
#  330,
#  338,
#  368,
#  388,
#  388,
#  403,
#  410,
#  419,
#  422,
#  423,
#  425,
#  426,
#  431,
#  445,
#  459,
#  462,
#  463,
#  469,
#  491,
#  493,
#  494,
#  496,
#  498,
#  506,
#  541,
#  560,
#  576,
#  597,
#  598,
#  612,
#  623,
#  630,
#  638,
#  642,
#  645,
#  663,
#  672,
#  678,
#  683,
#  693,
#  695,
#  707,
#  711,
#  713,
#  715,
#  721,
#  729,
#  736,
#  760,
#  769,
#  778,
#  813,
#  813,
#  826,
#  845,
#  845,
#  864,
#  875,
#  877,
#  885,
#  891,
#  911,
#  922,
#  956,
#  970,
#  971,
#  972,
#  972,
#  981,
#  986,
#  988,
#  998]

# %%
# %time sort(thousand_sample)
# Out:
# CPU times: user 34.8 ms, sys: 1.78 ms, total: 36.5 ms
# Wall time: 36.9 ms
# [0,
#  0,
#  1,
#  2,
#  3,
#  3,
#  4,
#  5,
#  9,
#  9,
#  9,
#  10,
#  10,
#  11,
#  11,
#  11,
#  11,
#  12,
#  12,
#  13,
#  15,
#  15,
#  20,
#  22,
#  23,
#  23,
#  24,
#  24,
#  25,
#  25,
#  27,
#  32,
#  33,
#  33,
#  34,
#  34,
#  34,
#  35,
#  35,
#  36,
#  36,
#  41,
#  42,
#  43,
#  43,
#  44,
#  45,
#  46,
#  46,
#  47,
#  48,
#  49,
#  49,
#  53,
#  53,
#  53,
#  53,
#  53,
#  55,
#  56,
#  57,
#  59,
#  60,
#  60,
#  63,
#  64,
#  67,
#  68,
#  69,
#  69,
#  70,
#  72,
#  73,
#  73,
#  74,
#  75,
#  77,
#  77,
#  79,
#  80,
#  81,
#  81,
#  82,
#  83,
#  84,
#  85,
#  85,
#  86,
#  86,
#  87,
#  87,
#  88,
#  88,
#  89,
#  91,
#  91,
#  92,
#  92,
#  92,
#  95,
#  95,
#  95,
#  95,
#  95,
#  98,
#  99,
#  99,
#  100,
#  100,
#  100,
#  101,
#  101,
#  101,
#  101,
#  102,
#  103,
#  104,
#  104,
#  104,
#  108,
#  109,
#  110,
#  110,
#  110,
#  111,
#  113,
#  115,
#  116,
#  117,
#  117,
#  118,
#  118,
#  118,
#  120,
#  120,
#  121,
#  121,
#  123,
#  123,
#  124,
#  124,
#  125,
#  125,
#  126,
#  126,
#  128,
#  130,
#  131,
#  132,
#  133,
#  133,
#  133,
#  134,
#  134,
#  135,
#  135,
#  136,
#  136,
#  137,
#  137,
#  137,
#  138,
#  139,
#  140,
#  142,
#  144,
#  144,
#  144,
#  145,
#  146,
#  147,
#  147,
#  147,
#  149,
#  150,
#  151,
#  152,
#  153,
#  153,
#  154,
#  154,
#  156,
#  156,
#  157,
#  157,
#  157,
#  158,
#  160,
#  160,
#  161,
#  162,
#  164,
#  165,
#  167,
#  167,
#  169,
#  171,
#  172,
#  172,
#  173,
#  173,
#  173,
#  174,
#  176,
#  177,
#  178,
#  179,
#  181,
#  181,
#  181,
#  181,
#  182,
#  184,
#  185,
#  188,
#  188,
#  189,
#  192,
#  192,
#  192,
#  196,
#  197,
#  197,
#  199,
#  200,
#  200,
#  201,
#  203,
#  204,
#  204,
#  206,
#  209,
#  211,
#  212,
#  212,
#  212,
#  213,
#  215,
#  216,
#  216,
#  216,
#  217,
#  217,
#  219,
#  220,
#  221,
#  226,
#  227,
#  230,
#  230,
#  231,
#  231,
#  232,
#  232,
#  232,
#  233,
#  233,
#  234,
#  237,
#  237,
#  238,
#  241,
#  242,
#  244,
#  245,
#  246,
#  246,
#  247,
#  249,
#  249,
#  250,
#  254,
#  255,
#  255,
#  255,
#  256,
#  256,
#  257,
#  257,
#  257,
#  259,
#  260,
#  260,
#  261,
#  263,
#  263,
#  263,
#  264,
#  265,
#  265,
#  265,
#  266,
#  267,
#  268,
#  269,
#  269,
#  270,
#  271,
#  272,
#  273,
#  274,
#  274,
#  275,
#  276,
#  277,
#  277,
#  279,
#  280,
#  280,
#  281,
#  282,
#  283,
#  283,
#  285,
#  285,
#  286,
#  287,
#  287,
#  287,
#  288,
#  288,
#  288,
#  289,
#  291,
#  291,
#  292,
#  292,
#  294,
#  294,
#  294,
#  296,
#  297,
#  299,
#  299,
#  300,
#  300,
#  301,
#  302,
#  303,
#  304,
#  304,
#  305,
#  306,
#  306,
#  307,
#  307,
#  309,
#  309,
#  309,
#  310,
#  311,
#  314,
#  315,
#  315,
#  315,
#  316,
#  317,
#  317,
#  319,
#  320,
#  321,
#  321,
#  321,
#  323,
#  323,
#  324,
#  328,
#  328,
#  328,
#  329,
#  329,
#  330,
#  330,
#  332,
#  333,
#  334,
#  334,
#  335,
#  335,
#  335,
#  335,
#  338,
#  339,
#  340,
#  341,
#  341,
#  341,
#  342,
#  343,
#  345,
#  345,
#  347,
#  348,
#  348,
#  349,
#  349,
#  350,
#  358,
#  358,
#  361,
#  362,
#  362,
#  363,
#  365,
#  366,
#  367,
#  369,
#  372,
#  375,
#  375,
#  376,
#  377,
#  381,
#  382,
#  383,
#  384,
#  385,
#  385,
#  385,
#  387,
#  390,
#  391,
#  391,
#  392,
#  393,
#  394,
#  394,
#  396,
#  396,
#  397,
#  398,
#  401,
#  401,
#  403,
#  403,
#  404,
#  405,
#  407,
#  408,
#  409,
#  409,
#  410,
#  411,
#  412,
#  415,
#  415,
#  416,
#  416,
#  416,
#  417,
#  417,
#  418,
#  419,
#  419,
#  420,
#  424,
#  426,
#  427,
#  429,
#  429,
#  429,
#  430,
#  431,
#  431,
#  432,
#  433,
#  434,
#  435,
#  435,
#  435,
#  437,
#  439,
#  441,
#  441,
#  442,
#  443,
#  444,
#  445,
#  446,
#  446,
#  446,
#  447,
#  447,
#  449,
#  451,
#  453,
#  456,
#  458,
#  458,
#  459,
#  461,
#  461,
#  461,
#  462,
#  462,
#  463,
#  463,
#  465,
#  467,
#  469,
#  471,
#  472,
#  474,
#  475,
#  478,
#  478,
#  479,
#  479,
#  480,
#  480,
#  482,
#  483,
#  483,
#  487,
#  490,
#  490,
#  490,
#  491,
#  494,
#  496,
#  497,
#  499,
#  501,
#  501,
#  501,
#  502,
#  505,
#  506,
#  506,
#  508,
#  509,
#  512,
#  512,
#  514,
#  516,
#  517,
#  517,
#  518,
#  518,
#  519,
#  521,
#  522,
#  525,
#  526,
#  528,
#  528,
#  528,
#  529,
#  532,
#  533,
#  534,
#  537,
#  538,
#  538,
#  539,
#  540,
#  542,
#  543,
#  546,
#  546,
#  550,
#  551,
#  551,
#  553,
#  553,
#  555,
#  557,
#  557,
#  558,
#  561,
#  561,
#  565,
#  566,
#  566,
#  566,
#  567,
#  568,
#  569,
#  570,
#  571,
#  571,
#  572,
#  572,
#  574,
#  575,
#  575,
#  575,
#  576,
#  576,
#  578,
#  579,
#  580,
#  581,
#  582,
#  583,
#  584,
#  584,
#  587,
#  587,
#  587,
#  588,
#  589,
#  590,
#  590,
#  591,
#  593,
#  593,
#  594,
#  596,
#  596,
#  596,
#  599,
#  601,
#  601,
#  602,
#  603,
#  603,
#  603,
#  603,
#  605,
#  606,
#  607,
#  607,
#  608,
#  610,
#  613,
#  613,
#  614,
#  614,
#  615,
#  616,
#  617,
#  617,
#  619,
#  620,
#  620,
#  622,
#  622,
#  624,
#  625,
#  627,
#  629,
#  631,
#  633,
#  633,
#  634,
#  637,
#  637,
#  639,
#  640,
#  640,
#  645,
#  646,
#  649,
#  650,
#  650,
#  650,
#  652,
#  654,
#  655,
#  655,
#  657,
#  657,
#  659,
#  662,
#  663,
#  663,
#  663,
#  665,
#  668,
#  669,
#  670,
#  670,
#  670,
#  670,
#  671,
#  671,
#  674,
#  674,
#  675,
#  676,
#  676,
#  678,
#  680,
#  681,
#  681,
#  683,
#  683,
#  683,
#  684,
#  685,
#  685,
#  685,
#  686,
#  686,
#  686,
#  686,
#  687,
#  687,
#  688,
#  689,
#  689,
#  690,
#  691,
#  691,
#  695,
#  695,
#  696,
#  697,
#  700,
#  700,
#  702,
#  702,
#  703,
#  704,
#  705,
#  706,
#  707,
#  709,
#  709,
#  709,
#  711,
#  712,
#  713,
#  714,
#  717,
#  719,
#  727,
#  727,
#  728,
#  729,
#  730,
#  730,
#  730,
#  731,
#  732,
#  733,
#  733,
#  733,
#  734,
#  735,
#  736,
#  737,
#  740,
#  741,
#  742,
#  744,
#  745,
#  745,
#  747,
#  747,
#  747,
#  748,
#  751,
#  751,
#  751,
#  752,
#  753,
#  755,
#  755,
#  756,
#  756,
#  757,
#  758,
#  760,
#  762,
#  763,
#  763,
#  765,
#  767,
#  768,
#  769,
#  770,
#  772,
#  772,
#  773,
#  774,
#  774,
#  775,
#  777,
#  777,
#  778,
#  779,
#  779,
#  780,
#  781,
#  781,
#  781,
#  782,
#  782,
#  782,
#  783,
#  785,
#  788,
#  788,
#  791,
#  791,
#  792,
#  792,
#  793,
#  794,
#  795,
#  797,
#  797,
#  799,
#  799,
#  800,
#  800,
#  801,
#  801,
#  802,
#  802,
#  804,
#  805,
#  806,
#  810,
#  811,
#  811,
#  811,
#  814,
#  815,
#  815,
#  815,
#  816,
#  816,
#  816,
#  816,
#  817,
#  818,
#  818,
#  819,
#  819,
#  820,
#  823,
#  826,
#  829,
#  830,
#  830,
#  831,
#  831,
#  831,
#  831,
#  832,
#  834,
#  834,
#  837,
#  837,
#  838,
#  840,
#  840,
#  843,
#  845,
#  848,
#  848,
#  850,
#  851,
#  851,
#  856,
#  858,
#  858,
#  861,
#  862,
#  862,
#  863,
#  866,
#  867,
#  867,
#  867,
#  867,
#  868,
#  868,
#  870,
#  871,
#  874,
#  876,
#  878,
#  878,
#  879,
#  879,
#  880,
#  880,
#  881,
#  883,
#  885,
#  885,
#  885,
#  885,
#  886,
#  888,
#  888,
#  888,
#  889,
#  890,
#  890,
#  891,
#  893,
#  893,
#  894,
#  894,
#  895,
#  895,
#  896,
#  896,
#  896,
#  897,
#  898,
#  899,
#  900,
#  901,
#  902,
#  902,
#  902,
#  906,
#  908,
#  910,
#  910,
#  911,
#  912,
#  912,
#  912,
#  913,
#  916,
#  917,
#  917,
#  918,
#  919,
#  921,
#  921,
#  921,
#  922,
#  924,
#  925,
#  926,
#  927,
#  927,
#  927,
#  929,
#  930,
#  930,
#  931,
#  932,
#  932,
#  935,
#  935,
#  935,
#  938,
#  939,
#  940,
#  941,
#  941,
#  944,
#  946,
#  946,
#  947,
#  948,
#  949,
#  950,
#  950,
#  953,
#  953,
#  953,
#  953,
#  957,
#  960,
#  961,
#  962,
#  962,
#  962,
#  963,
#  964,
#  965,
#  966,
#  967,
#  969,
#  972,
#  972,
#  973,
#  973,
#  974,
#  974,
#  976,
#  977,
#  978,
#  980,
#  982,
#  983,
#  983,
#  985,
#  986,
#  988,
#  991,
#  991,
#  991,
#  992,
#  995,
#  998,
#  998,
#  999,
#  999,
#  1000]
