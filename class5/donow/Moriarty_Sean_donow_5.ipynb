# %%
import pandas as pd
import pg8000 as pg
from sqlalchemy import create_engine
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime, timedelta

# %%
engine = create_engine('postgresql+pg8000://dot_student:qgis@training.c1erymiua9dx.us-east-1.rds.amazonaws.com:5432/training')

# %%
con=engine.raw_connection()

# %%
df=pd.read_sql_query('select * from noise_311', con=con)

# %%
df.head()
# Out:
#    b'unique_key'     b'created_date'      b'closed_date' b'agency'  \
# 0       28792167 2014-08-31 23:59:00 2014-09-01 03:52:00      NYPD
# 1       28789088 2014-08-31 23:56:00 2014-09-01 06:17:00      NYPD
# 2       28791854 2014-08-31 23:54:00 2014-09-01 01:29:00      NYPD
# 3       28789936 2014-08-31 23:52:00 2014-09-01 02:53:00      NYPD
# 4       28789931 2014-08-31 23:47:00 2014-09-01 01:06:00      NYPD
#
#                     b'agency_name'        b'complaint_type'     b'descriptor'  \
# 0  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 1  New York City Police Department          Noise - Vehicle   Car/Truck Music
# 2  New York City Police Department       Noise - Commercial  Loud Music/Party
# 3  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 4  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
#
#       b'location_type' b'incident_zip'   b'incident_address'  \
# ...

# %%
for bytes_name in df.columns:
    df.rename(columns = {bytes_name:bytes_name.decode('utf-8')}, inplace = True)

# %%
df.head()
# Out:
#    unique_key        created_date         closed_date agency  \
# 0    28792167 2014-08-31 23:59:00 2014-09-01 03:52:00   NYPD
# 1    28789088 2014-08-31 23:56:00 2014-09-01 06:17:00   NYPD
# 2    28791854 2014-08-31 23:54:00 2014-09-01 01:29:00   NYPD
# 3    28789936 2014-08-31 23:52:00 2014-09-01 02:53:00   NYPD
# 4    28789931 2014-08-31 23:47:00 2014-09-01 01:06:00   NYPD
#
#                        agency_name           complaint_type        descriptor  \
# 0  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 1  New York City Police Department          Noise - Vehicle   Car/Truck Music
# 2  New York City Police Department       Noise - Commercial  Loud Music/Party
# 3  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 4  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
#
#          location_type incident_zip      incident_address  \
# 0      Street/Sidewalk        11222  200 KINGSLAND AVENUE
# ...

# %%
len(df)
# Out:
# 37615

# %%
df['open_duration']=df['closed_date']-df['created_date']

# %%
df['open_duration'].head(5)
# Out:
# 0   03:53:00
# 1   06:21:00
# 2   01:35:00
# 3   03:01:00
# 4   01:19:00
# Name: open_duration, dtype: timedelta64[ns]

# %%
df.groupby(by='agency').mean()
# Out:
#         unique_key  x_coordinate   y_coordinate   latitude  longitude
# agency
# DEP       28479030  1.002513e+06  204514.087172  40.727968 -73.934065
# DSNY      28441464  1.005781e+06  205684.000000  40.731180 -73.922281
# EDC       28463637  9.949129e+05  208390.951768  40.738636 -73.961490
# NYPD      28480302  1.002381e+06  213668.653246  40.753113 -73.934536

# %%
df.index=df['created_date']

# %%
df.head(5)
# Out:
#                      unique_key        created_date         closed_date  \
# created_date
# 2014-08-31 23:59:00    28792167 2014-08-31 23:59:00 2014-09-01 03:52:00
# 2014-08-31 23:56:00    28789088 2014-08-31 23:56:00 2014-09-01 06:17:00
# 2014-08-31 23:54:00    28791854 2014-08-31 23:54:00 2014-09-01 01:29:00
# 2014-08-31 23:52:00    28789936 2014-08-31 23:52:00 2014-09-01 02:53:00
# 2014-08-31 23:47:00    28789931 2014-08-31 23:47:00 2014-09-01 01:06:00
#
#                     agency                      agency_name  \
# created_date
# 2014-08-31 23:59:00   NYPD  New York City Police Department
# 2014-08-31 23:56:00   NYPD  New York City Police Department
# 2014-08-31 23:54:00   NYPD  New York City Police Department
# 2014-08-31 23:52:00   NYPD  New York City Police Department
# 2014-08-31 23:47:00   NYPD  New York City Police Department
#
#                               complaint_type        descriptor  \
# created_date
# ...

# %%
df['open_duration_sec']=.total_seconds()
# Out:
# 13980.0

# %%
lambda
