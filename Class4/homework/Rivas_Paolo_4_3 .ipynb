# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
# %matplotlib inline
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
from scipy.stats import kurtosis

# %%
df = pd.read_csv("heights_weights_genders.csv")

# %%
df.describe()
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989699

# %% [markdown]
# ## This two variables have slightly positive skewness and negative kurtosis!
# This means that data in both is centered and slightly platykurtic (-). They are fairly representative.

# %%
df.skew()
# Out:
# Height    0.049369
# Weight    0.032955
# dtype: float64

# %%
df.kurtosis()
# Out:
# Height   -0.474134
# Weight   -0.794618
# dtype: float64

# %%
This two variables are not skweed

# %%
df['Height'].plot.box()

# %%
df['Weight'].plot.box()

# %% [markdown]
# ## This is a very strong corralation! r= 0.92
# Sometimes the problem with really strong correlations that are not spurious is that they are very obvios. This association dont need statistical prove. They are common sense.

# %%
df.corr()
# Out:
#           Height    Weight
# Height  1.000000  0.924756
# Weight  0.924756  1.000000

# %%
x=df['Weight']
y=df['Height']
fig, ax = plt.subplots(figsize=(9,7))
fit = np.polyfit(x, y, deg=1)
ax.plot(x, fit[0] * x + fit[1], color='red')
ax.scatter(x, y)
ax.set_xlabel('Weight')
ax.set_ylabel('Height')

# %% [markdown]
# ## Corralation still strong for male or women (r > 0.8).

# %%
df.groupby('Gender').corr()
# Out:
#                  Height    Weight
# Gender
# Female Height  1.000000  0.849609
#        Weight  0.849609  1.000000
# Male   Height  1.000000  0.862979
#        Weight  0.862979  1.000000

# %%
df.groupby('Gender').plot(kind='scatter', x='Weight', y='Height')
# Out:
# Gender
# Female    Axes(0.125,0.125;0.775x0.775)
# Male      Axes(0.125,0.125;0.775x0.775)
# dtype: object
